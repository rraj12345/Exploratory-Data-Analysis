# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HRMS.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.shape
# Out:
# (311, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
#Cleaning the data

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
207/311
# Out:
# 0.6655948553054662

# %%
df.fillna('0', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
#TOP SLARY EMPLOYEE

# %%
df.head(2)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# ...

# %%
a = df[['Employee_Name','Salary']].sort_values(by = 'Salary',ascending=False).reset_index(drop=True).head(5)
a
# Out:
#       Employee_Name  Salary
# 0       King, Janet  250000
# 1  Zamora, Jennifer  220450
# 2   Houlihan, Debra  180000
# 3       Foss, Jason  178000
# 4    Corleone, Vito  170500

# %%
plt.figure(figsize=(10,5))
plt.bar(x = a['Employee_Name'], height = a['Salary'], color='#4C72B0', edgecolor='white', linewidth=1)
plt.xlabel('Employee Name',fontsize=10)
plt.ylabel('Salary',fontsize=10)
plt.title('Top Salary Employee',fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
#Employees who need special attention
#Performance Improvement Program

# %%
b = df['PerformanceScore'].value_counts()
b = pd.DataFrame(b)

# %%
b
# Out:
#                    count
# PerformanceScore
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13

# %%
sns.countplot(x='PerformanceScore', data=df, palette=['Red','Black','Green','Blue'])
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('PerformanceScore')
plt.show()

# %%
PIP_PEOPLE = df[df['PerformanceScore']=='PIP'].Employee_Name
PIP_PEOPLE = pd.DataFrame(PIP_PEOPLE)
PIP_PEOPLE
# Out:
#            Employee_Name
# 67         Delarge, Alex
# 69       Desimone, Carl
# 72     Dietrich, Jenna
# 83        Erilus, Angela
# 90   Fernandes, Nilson
# 91            Fett, Boba
# 95         Forrest, Alex
# 112       Gonzalez, Juan
# 188          Miller, Ned
# 205         O'hare, Lynn
# 263     Sparks, Taylor
# 267   Stansfield, Norman
# 307   Ybarra, Catherine

# %%
#Number of Absenses

# %%
c = df['Absences'].value_counts().sort_values(ascending=False).head(5)
c = pd.DataFrame(c)
c
# Out:
#           count
# Absences
# 4            23
# 16           23
# 7            21
# 2            21
# 15           20

# %%
sns.barplot(x='Absences', y='count', data=c, palette=['Red','Black','Green','Blue','Purple'])
plt.xlabel('Total_Employees')
plt.ylabel('nO_oF_Days_Absent')
plt.title('Employees_Absences')
plt.show()

# %%
#Whether the employees are married or not

# %%
df['MarriedID'].value_counts()
# Out:
# MarriedID
# 0    187
# 1    124
# Name: count, dtype: int64

# %%
sns.countplot(x='MarriedID', data=df, palette=['Red','Black'])
plt.xlabel('Married')
plt.ylabel('Count')
plt.title('Married or Not')
plt.show()

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
#SpecialProjectCount

# %%
d = df[df['SpecialProjectsCount'] != 0]
d.sort_values( by = 'SpecialProjectsCount',ascending=False)
d.shape
# Out:
# (70, 36)

# %%
e = df[df['SpecialProjectsCount'] == 0]
e.sort_values( by = 'SpecialProjectsCount',ascending=False)
e.shape
# Out:
# (241, 36)

# %%
sns.countplot(x='SpecialProjectsCount', data=df, palette=['Red','Black'])
plt.xlabel('SpecialProjectsCount')
plt.ylabel('Count')
plt.title('SpecialProjectsCount')
plt.show()

# %%
#Comparision of Highest Salary and Lowst Salary

# %%
df['Salary'].sort_values(ascending=False).head(5)
# Out:
# 150    250000
# 308    220450
# 131    180000
# 96     178000
# 55     170500
# Name: Salary, dtype: int64

# %%
df['Salary'].sort_values(ascending=False).tail(5)
# Out:
# 152    45433
# 176    45395
# 231    45115
# 140    45069
# 310    45046
# Name: Salary, dtype: int64

# %%
c = [1,2,3,4,5]

xx = df['Salary'].sort_values(ascending=False).head(5)
yy = df['Salary'].sort_values(ascending=False).tail(5)

plt.bar(c, xx,color = 'red', label = 'Top_5_Highest_Salary')
plt.bar(c, yy,color = 'green', label = 'Bottom_5_Lowest_Salary')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.title('Highest and Lowest Salary')
plt.show()

# %%
#Source_of_Recuritment

# %%
df['RecruitmentSource'].unique()
# Out:
# array(['LinkedIn', 'Indeed', 'Google Search', 'Employee Referral',
#        'Diversity Job Fair', 'On-line Web application', 'CareerBuilder',
#        'Website', 'Other'], dtype=object)

# %%
l = df['RecruitmentSource'].value_counts().sort_values(ascending=True)
l
# Out:
# RecruitmentSource
# On-line Web application     1
# Other                       2
# Website                    13
# CareerBuilder              23
# Diversity Job Fair         29
# Employee Referral          31
# Google Search              49
# LinkedIn                   76
# Indeed                     87
# Name: count, dtype: int64

# %%
sns.lineplot(x=l.index, y=l.values,palette='Red',marker='o')
plt.xlabel('RecruitmentSource')
plt.ylabel('Count')
plt.title('RecruitmentSource')
plt.xticks(rotation=90)
plt.show()

# %%
#Employee_Satisfaction

# %%
df['EmpSatisfaction']
# Out:
# 0      5
# 1      3
# 2      3
# 3      5
# 4      4
#       ..
# 306    4
# 307    2
# 308    5
# 309    3
# 310    5
# Name: EmpSatisfaction, Length: 311, dtype: int64

# %%
e = df['EmpSatisfaction'].value_counts()
e
# Out:
# EmpSatisfaction
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: count, dtype: int64

# %%
plt.stem(e.index,e.values)
plt.xlabel('EmpSatisfaction')
plt.ylabel('Count')
plt.title('Employee_Satisfaction')
plt.show()

# %%
#Bivariate Analysis

# %%
#Outliers in salary department wise

# %%
plt.figure(figsize = (10,5))

sns.boxplot(x = 'Department', y = 'Salary',data = df , palette='viridis')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.xticks(rotation = -45)
plt.yticks(rotation = -60)
plt.title('Outliers in salary department wise')
plt.show()

# %%
df['Position']
# Out:
# 0       Production Technician I
# 1                       Sr. DBA
# 2      Production Technician II
# 3       Production Technician I
# 4       Production Technician I
#                  ...
# 306    Production Technician II
# 307     Production Technician I
# 308                         CIO
# 309                Data Analyst
# 310     Production Technician I
# Name: Position, Length: 311, dtype: object

# %%
df['EngagementSurvey']
# Out:
# 0      4.60
# 1      4.96
# 2      3.02
# 3      4.84
# 4      5.00
#        ...
# 306    4.07
# 307    3.20
# 308    4.60
# 309    5.00
# 310    4.50
# Name: EngagementSurvey, Length: 311, dtype: float64

# %%
plt.figure(figsize = (20,10))

sns.barplot(x = 'Position', y = 'EngagementSurvey',data = df, palette='viridis')
plt.xlabel('Position')
plt.xticks(rotation = 85)
plt.ylabel('EngagementSurvey')
plt.title('Position vs EngagementSurvey')
plt.show()

# %%
#Marital Status by gender

# %%
plt.figure(figsize = (10,5))
sns.countplot(x='MaritalDesc', hue = 'GenderID', data = df , palette= 'pastel')
plt.xlabel('MaritalDesc')
plt.ylabel('Count')
plt.title('Marital Status by gender')
plt.show()

# %%
#What is the average Engemant score in each department

# %%
aa = df.groupby('Department')['EngagementSurvey'].mean()
aa
# Out:
# Department
# Admin Offices           4.393333
# Executive Office        4.830000
# IT/IS                   4.154000
# Production              4.129569
# Sales                   3.818710
# Software Engineering    4.061818
# Name: EngagementSurvey, dtype: float64

# %%
#How many  employees have terminated from each position?

# %%
terminated_employees_by_position = df[df['Termd'] == 1].groupby('Position')['Employee_Name'].count()
terminated_employees_by_position
# Out:
# Position
# Administrative Assistant     2
# Area Sales Manager           4
# Data Analyst                 1
# Data Analyst                 1
# Database Administrator       3
# Enterprise Architect         1
# IT Manager - DB              1
# Network Engineer             1
# Principal Data Architect     1
# Production Manager           5
# Production Technician I     52
# Production Technician II    26
# Sales Manager                1
# Software Engineer            4
# Sr. DBA                      1
# Name: Employee_Name, dtype: int64

# %%
#Question 3: What is the median salary for male and female employees?

# %%
median_salary_by_gender = df.groupby('Sex')['Salary'].median()
median_salary_by_gender
# Out:
# Sex
# F     62066.5
# M     63353.0
# Name: Salary, dtype: float64

# %%
#Question 4: How many employees have been terminated for each reason?

# %%
termination_reason_counts = df[df['Termd'] == 1].groupby('TermReason')['Employee_Name'].count()
termination_reason_counts.head(5)
# Out:
# TermReason
# Another position                 20
# Fatal attraction                  1
# Learned that he is a gangster     1
# attendance                        7
# career change                     9
# Name: Employee_Name, dtype: int64

# %%
#Question5  What is the maximum number of absences taken by employees in each department?

# %%
max_absences_by_department = df.groupby('Department')['Absences'].max()
max_absences_by_department
# Out:
# Department
# Admin Offices           20
# Executive Office        10
# IT/IS                   20
# Production              20
# Sales                   20
# Software Engineering    19
# Name: Absences, dtype: int64

# %%
#Question 6: What are the total absences and average engagement survey score for each department?

# %%
department_summary = df.groupby('Department').agg({'Absences': 'sum', 'EngagementSurvey': 'mean'})
department_summary
# Out:
#                       Absences  EngagementSurvey
# Department
# Admin Offices               78          4.393333
# Executive Office            10          4.830000
# IT/IS                      522          4.154000
# Production                2120          4.129569
# Sales                      358          3.818710
# Software Engineering        96          4.061818

# %%
#Q7)What is the maximum salary and minimum days late in the last 30 days for employees in each position?

# %%
position_summary = df.groupby('Position').agg({'Salary': 'max', 'DaysLateLast30': 'min'})
position_summary
# Out:
#                               Salary  DaysLateLast30
# Position
# Accountant I                   64520               0
# Administrative Assistant       55000               0
# Area Sales Manager             74326               0
# BI Developer                   99020               0
# BI Director                   110929               0
# CIO                           220450               0
# Data Analyst                   93554               0
# Data Analyst                   88527               0
# Data Architect                150290               0
# Database Administrator        114800               0
# Director of Operations        170500               0
# Director of Sales             180000               0
# Enterprise Architect          103613               0
# IT Director                   178000               0
# IT Manager - DB               148999               0
# IT Manager - Infra            157000               4
# ...

# %%
#Q9) How many terminated employees were there in each department and what is the average employee satisfaction level among them?

# %%
terminated_summary = df[df['Termd'] == 1].groupby('Department').agg({'Employee_Name': 'count', 'EmpSatisfaction': 'mean'})
terminated_summary.columns = ['Terminated_Count', 'Average_EmpSatisfaction']

# %%
#Q10) What is the earliest and latest date of hire for employees in each manager's team?

# %%
manager_hire_dates = df.groupby('ManagerName').agg({'DateofHire': ['min', 'max']})
manager_hire_dates
# Out:
#                    DateofHire
#                           min        max
# ManagerName
# Alex Sweetwater      1/9/2012   7/7/2014
# Amy Dunn            1/10/2011  9/29/2014
# Board of Directors   1/5/2009   7/2/2012
# Brandon R. LeBlanc   1/6/2014  9/29/2014
# Brannon Miller      1/10/2011   9/2/2008
# Brian Champaigne     1/7/2017  4/20/2017
# David Stanley       1/10/2011  9/29/2014
# Debra Houlihan      11/7/2011   5/5/2014
# Elijiah Gray        1/10/2011  9/29/2014
# Eric Dougall        1/21/2011   9/5/2012
# Janet King          1/10/2011  9/30/2013
# Jennifer Zamora     1/20/2013   9/6/2016
# John Smith           1/5/2015  9/29/2014
# Kelley Spirea       1/10/2011  9/30/2013
# Ketsia Liebig       1/10/2011  9/30/2013
# Kissy Sullivan      1/10/2011  9/30/2013
# Lynn Daneault       1/10/2011   9/6/2011
# Michael Albert       1/5/2009  9/30/2013
# Peter Monroe         1/5/2015  9/30/2014
# Simon Roup           1/5/2015   7/7/2014
# Webster Butler      1/10/2011  9/30/2013

# %%
'''
Some interesting insights from the analysis:

Indeed and LinkedIn are the top platforms from where the company hired most of the candidates
187 employees are unmarried, while 124 are married
As we can see,Out of 311 Employees 70 Employees have the experience of atleast 1 special project and remaining 241 Employees have not done any special project
13 employees are struggling to give their best performance, need a Performance Improvement Plan (PIP)
'''
# Out:
# '\nSome interesting insights from the analysis:\n\nIndeed and LinkedIn are the top platforms from where the company hired most of the candidates\n187 employees are unmarried, while 124 are married\nAs we can see,Out of 311 Employees 70 Employees have the experience of atleast 1 special project and remaining 241 Employees have not done any special project\n13 employees are struggling to give their best performance, need a Performance Improvement Plan (PIP)\n'

# %%
'''
----------------------------------------------------------------END------------------------------------------------------------------------
'''
# Out:
# '\n----------------------------------------------------------------END------------------------------------------------------------------------\n'
